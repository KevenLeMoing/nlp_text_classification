# %%
import pandas as pd

#Importation de BeautifulSoup
import bs4 as bs

#Importation de re pour traiter les expressions régulières
import re

# Librairie contenant tous les stop-words
import nltk
from nltk.corpus import stopwords

# %%
# ---------------------------------- 1er choix

# data = pd.read_csv('\Users\k_lemo\Documents\Stage\Data_EPO\data1_0.csv')

# ---------------------------------- 2ième choix

data = pd.read_csv('\Users\k_lemo\Documents\Stage\Data_EPO\data1_1.csv')

# %%
#On retire les balises HTML
clean = [bs.BeautifulSoup(data['full_text'][i]).get_text() for i in range(len(data.index))]
data['full_text'] = clean
data
# Out:
# C:\Users\k_lemo\AppData\Local\Continuum\Anaconda2\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
#          doc_id       cpc_1           cpc_2  \
# 0     294285027        E03D   11/12
# 1     294490073        G11B   23/40
# 2     296906943        G06M    1/00
# 3     294827982        A63H   33/04
# 4     328236491  D08303000O             NaN
# 5     325709882  074015000X             NaN
# 6     303003293        E01B   31/20
# 7     303117077        A61Q    5/06
# 8     376604586        C09B   61/00
# 9     376607600        A24D    1/00
# 10    333873740        H02H    7/0851
# 11    406442150        A61C   19/04
# 12    293893551        E04H    5/04
# 13    295496804        A43B    7/00
# 14    295459633        H02G    3/12
# 15    295207871        C07K   14/47
# 16    295495927        G01L    1/248
# 17    295107580        H01G    4/228
# 18    294338943        C09K    3/24
# 19    304425341        C03C   17/42
# 20    294432308        A61F    5/445
# 21    295273875        B23D   61/025
# 22    295170787        F16B   39/04
# 23    295302735        B23D   61/026
# 24    297869416        A01C   23/002
# 25    297146918        F41A   21/16
# 26    318526946        D06F   27/00
# 27    303987718        G01V    1/3817
# 28    304739591        C07C   33/26
# 29    304726303        F15D    1/10
# ...         ...         ...             ...
# 9970  304196534        C25D   11/22
# 9971  304663558        D01G   99/00
# 9972  304560250        D03D   39/223
# 9973  304482037        D04H    1/42
# 9974  304960848        D06M   13/2035
# 9975  304247222        D06N    3/06
# 9976  304445862        D21F    5/04
# 9977  304445922        A47G   27/0487
# 9978  305056798        E21B    7/022
# 9979  305298204        F01K   13/02
# 9980  304788438        F01P    7/165
# 9981  304962877        F04B   27/1804
# 9982  304054702        F04C   18/107
# 9983  304056286        F16C   19/26
# 9984  304713814        F16D    1/097
# 9985  304096495        G01L    3/102
# 9986  304541148        G01R   33/50
# 9987  305054178        G01N   33/241
# 9988  304838641        G02B    5/1895
# 9989  304498513        G03F    7/0047
# 9990  304669040        C04B   35/47
# 9991  304088478        D07B    7/025
# 9992  304688776        G01R    1/203
# 9993  304054714        H01R   43/05
# 9994  304495008        H01S    5/227
# 9995  304533277        H04N    5/907
# 9996  304686794        B01J   37/14
# 9997  304475789        B02C   15/001
# 9998  305008237        B22D   19/00
# 9999  304496767        B41M    5/529
#
#                                               full_text
# 0         Die Erfindung ist dadurch gekennzeichnet, ...
# 1         Darstellung des Brockens und seiner Umgebu...
# 2      1. Verwendung einer Schablone mit mehreren Au...
# 3      1. Das Spiel besteht aus 100 Holzteilen in de...
# 4     CLAIMThe ornamental design for a handlebar gri...
# 5     It 531.H. J. HABER, METHOD OF TREATING CHARCOA...
# 6     The embodiments of the invention in which an e...
# 7     1. In a hair treating method for imparting cur...
# 8     The red pigment preparation method of Fructus ...
# 9     A cigarette, have rough cylindrical tobacco co...
# 10    nichtig nichtigEinklemmsicherungssystem nach A...
# 11    Gerätesatz umfassend eine Anzahl von unterschi...
# 12     1. Kompakte komplett transportabele fabrikfer...
# 13     1. Krankengymnastisches Hilfsmittel zur Überw...
# 14     1. Verteiler für die elektrische Hausinstalla...
# 15     1. Gen mit der Sequenz gemäss Sequenz ID No. ...
# 16        Gerät zum Prüfen von Spannungen an Brillen...
# 17     1. Stromübertragungselement zur Anwendung bei...
# 18     1. Künstlicher Schnee bzw. Raureif; hergestel...
# 19    The existing waterproof glass has hydrophobic ...
# 20        Stoss-und schlagsicheres Stomakappenset zu...
# 21        Kreissägeblatt mit unterschiedlichen in ih...
# 22     1. Sicherungsmutter zur Verwendung bei Maschi...
# 23        Sägeblatt mit Räumschneiden dadurch gekenn...
# 24        Gülle-oder Klärschlammverteiler mit einer ...
# 25     1. Druckgas-Schusswaffe mit einem Lauf, dadur...
# 26    **WARNUNG** Ende CLMS Feld Kannt Anfang DESC u...
# 27    1. Mécanisme pour l'obtention d'un mouvement d...
# 28    WHAT IS CLAIMED IS: 1. 2,2'-Bis([alpha]-hydrox...
# 29    11 C L A I M S 1. Aerodynamic casing adaptable...
# ...                                                 ...
# 9970  This invention is a method regarding metal sal...
# 9971  Utilize and heat it in order to reduce a fibro...
# 9972  Shaping part of every self-powered looped pile...
# 9973  Disclose adhesive-bonded fabric, they for whet...
# 9974  This invention relates to one kind while heati...
# 9975  A complex gentle felt mode of production and p...
# 9976  Inhibit a dry technological method to the pape...
# 9977  A method for collecting the floor paving lock ...
# 9978  An apparatus and method for holing on the rock...
# 9979  The steam turbine power generation system incl...
# 9980  This device cools and disposes a cycle branch ...
# 9981  One swash plate compressor wave disc type comp...
# 9982  A kind of fluid compressor, including disposin...
# 9983  Pygmy and carrying capacity big roller bearing...
# 9984  One, one rotor block and one rotatory machiner...
# 9985  A method based on sensitive running torque of ...
# 9986  Magnetic resonance imaging (MRI) is at the tim...
# 9987  This invention has disclosed a method for gaug...
# 9988  A kind of diffraction multifocal optical eleme...
# 9989  Can in a kind of photosensitive ceramic coatin...
# 9990  This text introduces semi conductive ceramics ...
# 9991  A two-shot rotating type compresses the conduc...
# 9992  Deal with the system installation in water rhe...
# 9993  The electric wire processing unit includes the...
# 9994  This invention used in disappear reflecting la...
# 9995  The field storage apparatus supplies with PAL ...
# 9996  This invention involves having preparation whi...
# 9997  This invention involves a kind of roller disc ...
# 9998  A method for using the mould casting metal cas...
# 9999  One thermal transfer (TTP) receiving plate, wh...
#
# [10000 rows x 4 columns]

# %%
#On supprime tout ce qui relève de la ponctuation et du numérique
clean = [re.sub("[^a-zA-Z\xc4\xe4\xc9\xe9\xd6\xf6\xdc\xfc\xdf\xc0\xe0\xc2\xe2\xc6\xe6\xc7\xe7\xc8\xe8\xca\xea\xcb\xeb\xce\xee\xcf\xef\x8c\x9c\xd9\xf9\xdb\xfb]"," ",data['full_text'][i]) for i in range(len(data.index))]
data['full_text'] = clean
data
# Out:
#          doc_id       cpc_1           cpc_2  \
# 0     294285027        E03D   11/12
# 1     294490073        G11B   23/40
# 2     296906943        G06M    1/00
# 3     294827982        A63H   33/04
# 4     328236491  D08303000O             NaN
# 5     325709882  074015000X             NaN
# 6     303003293        E01B   31/20
# 7     303117077        A61Q    5/06
# 8     376604586        C09B   61/00
# 9     376607600        A24D    1/00
# 10    333873740        H02H    7/0851
# 11    406442150        A61C   19/04
# 12    293893551        E04H    5/04
# 13    295496804        A43B    7/00
# 14    295459633        H02G    3/12
# 15    295207871        C07K   14/47
# 16    295495927        G01L    1/248
# 17    295107580        H01G    4/228
# 18    294338943        C09K    3/24
# 19    304425341        C03C   17/42
# 20    294432308        A61F    5/445
# 21    295273875        B23D   61/025
# 22    295170787        F16B   39/04
# 23    295302735        B23D   61/026
# 24    297869416        A01C   23/002
# 25    297146918        F41A   21/16
# 26    318526946        D06F   27/00
# 27    303987718        G01V    1/3817
# 28    304739591        C07C   33/26
# 29    304726303        F15D    1/10
# ...         ...         ...             ...
# 9970  304196534        C25D   11/22
# 9971  304663558        D01G   99/00
# 9972  304560250        D03D   39/223
# 9973  304482037        D04H    1/42
# 9974  304960848        D06M   13/2035
# 9975  304247222        D06N    3/06
# 9976  304445862        D21F    5/04
# 9977  304445922        A47G   27/0487
# 9978  305056798        E21B    7/022
# 9979  305298204        F01K   13/02
# 9980  304788438        F01P    7/165
# 9981  304962877        F04B   27/1804
# 9982  304054702        F04C   18/107
# 9983  304056286        F16C   19/26
# 9984  304713814        F16D    1/097
# 9985  304096495        G01L    3/102
# 9986  304541148        G01R   33/50
# 9987  305054178        G01N   33/241
# 9988  304838641        G02B    5/1895
# 9989  304498513        G03F    7/0047
# 9990  304669040        C04B   35/47
# 9991  304088478        D07B    7/025
# 9992  304688776        G01R    1/203
# 9993  304054714        H01R   43/05
# 9994  304495008        H01S    5/227
# 9995  304533277        H04N    5/907
# 9996  304686794        B01J   37/14
# 9997  304475789        B02C   15/001
# 9998  305008237        B22D   19/00
# 9999  304496767        B41M    5/529
#
#                                               full_text
# 0         Die Erfindung ist dadurch gekennzeichnet  ...
# 1         Darstellung des Brockens und seiner Umgebu...
# 2         Verwendung einer Schablone mit mehreren Au...
# 3         Das Spiel besteht aus     Holzteilen in de...
# 4     CLAIMThe ornamental design for a handlebar gri...
# 5     It     H  J  HABER  METHOD OF TREATING CHARCOA...
# 6     The embodiments of the invention in which an e...
# 7        In a hair treating method for imparting cur...
# 8     The red pigment preparation method of Fructus ...
# 9     A cigarette  have rough cylindrical tobacco co...
# 10    nichtig nichtigEinklemmsicherungssystem nach A...
# 11    Gerätesatz umfassend eine Anzahl von unterschi...
# 12        Kompakte komplett transportabele fabrikfer...
# 13        Krankengymnastisches Hilfsmittel zur Überw...
# 14        Verteiler für die elektrische Hausinstalla...
# 15        Gen mit der Sequenz gemäss Sequenz ID No  ...
# 16        Gerät zum Prüfen von Spannungen an Brillen...
# 17        Stromübertragungselement zur Anwendung bei...
# 18        Künstlicher Schnee bzw  Raureif  hergestel...
# 19    The existing waterproof glass has hydrophobic ...
# 20        Stoss und schlagsicheres Stomakappenset zu...
# 21        Kreissägeblatt mit unterschiedlichen in ih...
# 22        Sicherungsmutter zur Verwendung bei Maschi...
# 23        Sägeblatt mit Räumschneiden dadurch gekenn...
# 24        Gülle oder Klärschlammverteiler mit einer ...
# 25        Druckgas Schusswaffe mit einem Lauf  dadur...
# 26      WARNUNG   Ende CLMS Feld Kannt Anfang DESC u...
# 27       Mécanisme pour l obtention d un mouvement d...
# 28    WHAT IS CLAIMED IS          Bis  alpha  hydrox...
# 29       C L A I M S    Aerodynamic casing adaptable...
# ...                                                 ...
# 9970  This invention is a method regarding metal sal...
# 9971  Utilize and heat it in order to reduce a fibro...
# 9972  Shaping part of every self powered looped pile...
# 9973  Disclose adhesive bonded fabric  they for whet...
# 9974  This invention relates to one kind while heati...
# 9975  A complex gentle felt mode of production and p...
# 9976  Inhibit a dry technological method to the pape...
# 9977  A method for collecting the floor paving lock ...
# 9978  An apparatus and method for holing on the rock...
# 9979  The steam turbine power generation system incl...
# 9980  This device cools and disposes a cycle branch ...
# 9981  One swash plate compressor wave disc type comp...
# 9982  A kind of fluid compressor  including disposin...
# 9983  Pygmy and carrying capacity big roller bearing...
# 9984  One  one rotor block and one rotatory machiner...
# 9985  A method based on sensitive running torque of ...
# 9986  Magnetic resonance imaging  MRI  is at the tim...
# 9987  This invention has disclosed a method for gaug...
# 9988  A kind of diffraction multifocal optical eleme...
# 9989  Can in a kind of photosensitive ceramic coatin...
# 9990  This text introduces semi conductive ceramics ...
# 9991  A two shot rotating type compresses the conduc...
# 9992  Deal with the system installation in water rhe...
# 9993  The electric wire processing unit includes the...
# 9994  This invention used in disappear reflecting la...
# 9995  The field storage apparatus supplies with PAL ...
# 9996  This invention involves having preparation whi...
# 9997  This invention involves a kind of roller disc ...
# 9998  A method for using the mould casting metal cas...
# 9999  One thermal transfer  TTP  receiving plate  wh...
#
# [10000 rows x 4 columns]

# %%
# On met tout le texte en caractère minuscule

#clean = [(data['full_text'][i]).lower() for i in range(len(data.index))]
#data['full_text'] = clean
#data

# %%
# Mise en forme des documents en listes de mots

#clean = [(data['full_text'][i]).split() for i in range(len(data.index))]
#data['full_text'] = clean
#data

# %%
# ---------------------------------- 1er choix

# data.to_csv('\Users\k_lemo\Documents\Stage\Data_EPO\data2_0.csv', sep=',', encoding='utf-8', index=False)

# ---------------------------------- 2ième choix

data.to_csv('\Users\k_lemo\Documents\Stage\Data_EPO\data2_1.csv', sep=',', encoding='utf-8', index=False)




data
