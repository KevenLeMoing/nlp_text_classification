# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('\Users\k_lemo\Documents\Stage\Data_EPO\KIME\metadata.csv')

# %%
data
# Out:
#              docId         type                             sectionID  \
# 0        310449512       Claims  efa88b92-a687-4f80-95d6-35cf8c42fe6d
# 1        309114555       Claims  1e26ec35-fd12-4f09-8bd1-cbc33624ff7c
# 2        310449512       Claims  ab03915c-afc3-4929-81f4-309dc660e9c9
# 3        309114555       Claims  54efeebe-cc25-48ab-b51d-b14516b550e7
# 4        309114555  Description  baa6c21f-57aa-4502-8936-bf7ce470f1d8
# 5        310449512  Description  49d88a87-3523-4e40-89f0-8e17611f840c
# 6        309114555  Description  5eecda41-d99c-46f0-91ca-af1aa93b058a
# 7        310449512  Description  87ce199c-63d1-40e6-82db-ea2393c505e2
# 8        389148456       Claims  04321bb9-9037-49b4-8b00-4e8b68c63cd3
# 9        389148456  Description  4bd6058c-1172-47a6-88b6-90786c3a7776
# 10       311531022       Claims  83a9d4f3-608e-4c58-9f45-0e9c92bfa5a5
# 11       311531022  Description  74e3e963-132d-449b-8b33-3e388e487156
# ...

# %%
# Extraction des sectionID pour pouvoir exporter les full_text depuis XML

data['sectionID'].to_csv('C:\Users\k_lemo\Documents\Stage\Data_EPO\KIME\metadata_sectionID.csv', sep=',', encoding='utf-8', index=False)
