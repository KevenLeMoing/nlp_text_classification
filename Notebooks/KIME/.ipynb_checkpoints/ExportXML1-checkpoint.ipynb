# %%
import csv
from csv import *
import pandas as pd
from pandas import *

#Importation de BeautifulSoup
import bs4 as bs
from bs4 import BeautifulSoup

#Importation de re pour traiter les expressions régulières
import re

# Librairie contenant tous les stop-words
import nltk
from nltk.corpus import stopwords

from lxml import etree
import xml.etree.ElementTree

import re

import io
from io import StringIO, BytesIO

import time

# %%
# Lecture du fichier CSV 

start_time = time.time()
data = read_csv('\Users\k_lemo\Documents\Stage\Data\KIME\XML\importXml1\XML_SPLIT\split_1.csv',error_bad_lines=False, iterator=True, chunksize=10000)
data = concat(data, ignore_index=True)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Skipping line 7: expected 2 fields, saw 3
# Skipping line 9: expected 2 fields, saw 3
# Skipping line 13: expected 2 fields, saw 3
# Skipping line 14: expected 2 fields, saw 3
# Skipping line 20: expected 2 fields, saw 3
# Skipping line 43: expected 2 fields, saw 3
# Skipping line 47: expected 2 fields, saw 5
# Skipping line 49: expected 2 fields, saw 3
# Skipping line 51: expected 2 fields, saw 5
# Skipping line 56: expected 2 fields, saw 3
# Skipping line 58: expected 2 fields, saw 5
# Skipping line 76: expected 2 fields, saw 4
# Skipping line 82: expected 2 fields, saw 3
# Skipping line 83: expected 2 fields, saw 4
# Skipping line 91: expected 2 fields, saw 3
# Skipping line 97: expected 2 fields, saw 3
# Skipping line 100: expected 2 fields, saw 5
# Skipping line 105: expected 2 fields, saw 5
# Skipping line 108: expected 2 fields, saw 4
# Skipping line 109: expected 2 fields, saw 3
# Skipping line 111: expected 2 fields, saw 3
# Skipping line 118: expected 2 fields, saw 5
# ...

# %%
data = data.ix[1:]
#data.columns = ['DocId','Fulltext']

# %%
# Import du fichier de test pour récupérer plusieurs balises cpc

data = read_csv('C:\Users\k_lemo\Documents\Stage\Data\KIME\XML\importXml1\Test\parsingtest2.csv',header=None)

# %%
#data = data.drop(['DocId'], axis=1)
data
# Out:
#                                                    0
# 0  <teiHeader><fileDesc><titleStmt><title>Patent ...

# %%
xml = data[0]
#root = etree.fromstring(xml)
root = etree.parse(StringIO(xml))
teiHeider = etree.SubElement(root, "teiHeider")
#teiHeider = etree.Element("teiHeider")
fileDesc = etree.SubElement(teiHeider, "fileDesc")
titleStmt = etree.SubElement(fileDesc, "titleStmt")
title = etree.SubElement(titleStmt, "title")
print (title.text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4ece756072f4> in <module>()
#       1 xml = data[0]
#       2 #root = etree.fromstring(xml)
# ----> 3 root = etree.parse(StringIO(xml))
#       4 teiHeider = etree.SubElement(root, "teiHeider")
#       5 #teiHeider = etree.Element("teiHeider")
#
# TypeError: initial_value must be unicode or None, not Series

# %%
#clean = [bs.BeautifulSoup(data['full_text'][i]).get_text() for i in range(len(data.index))]
#tree = [etree.parse(data['Fulltext'][i]).get_text() for i in range(len(data.index))]

tree = etree.parse('/Users/k_lemo/Documents/Stage/Data/KIME/XML/importXml1/Test/new2.xml')
print (tree.xpath("teiHeider/fileDesc/titleStmt/title").)

#for classification in tree.xpath("/teiHeider/profileDesc/textClass/classCode/ident"):
 #   print('a')
#  print(user.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-5c446b276cbd> in <module>()
#       3
#       4 tree = etree.parse('/Users/k_lemo/Documents/Stage/Data/KIME/XML/importXml1/Test/new2.xml')
# ----> 5 print (tree.xpath("teiHeider/fileDesc/titleStmt/title").text)
#       6
#       7 #for classification in tree.xpath("/teiHeider/profileDesc/textClass/classCode/ident"):
#
# AttributeError: 'list' object has no attribute 'text'

# %%
data[1].to_csv('C:\Users\k_lemo\Documents\Stage\Data\KIME\XML\importXml1\Test\iu.csv', quoting = csv.QUOTE_NONE, index=False, header=False)

# %%
def func(row):
    xml = ['<item>']
    for field in row.index:
        xml.append('  <field name="{0}">{1}</field>'.format(field, row[field]))
    xml.append('</item>')
    return '\n'.join(xml)

# %%
def to_xml(df, filename=None, mode='w'):
    def row_to_xml(row):
        xml = ['<item>']
        for i, col_name in enumerate(row.index):
            xml.append('  <field name="{0}">{1}</field>'.format(col_name, row.iloc[i]))
        xml.append('</item>')
        return '\n'.join(xml)
    res = '\n'.join(df.apply(row_to_xml, axis=1))

    if filename is None:
        return res
    with open(filename, mode) as f:
        f.write(res)

pd.DataFrame.to_xml = to_xml

# %%
for index, row in data.iterrows():
    if not row['DocId']:
        print('a')
    else:
        print('b')
    
    #if data['DocId'][i] == '':
    #print ('a')
# Out:
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# b
# ...

# %%
# On parse le xml

for index, row in data.iterrows():
    ft = row['Fulltext']
    ft_parse = etree.parse(StringIO(u"""\ft"""))
    ft_notags = etree.tostring(ft_parse, encoding='utf-8', method='text')
    row['Fulltext'] = ft_notags
# Out:
#   File "<string>", line unknown
# XMLSyntaxError: Start tag expected, '<' not found, line 1, column 1

# %%
# On parse le xml

for index, row in data.iterrows():
    ft = row['Fulltext']
    ft = BeautifulSoup(ft,"lxml").find('title')
    # ft = BeautifulSoup(ft,"lxml").find('ident')
    row['Fulltext'] = ft.text
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-1b7ec970c149> in <module>()
#       3 for index, row in data.iterrows():
#       4     ft = row['Fulltext']
# ----> 5     ft = BeautifulSoup(ft,"lxml").find('title')
#       6     row['Fulltext'] = ft.text
#       7 data
#
# C:\Users\k_lemo\AppData\Local\Continuum\Anaconda2\lib\site-packages\bs4\__init__.pyc in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     174         if hasattr(markup, 'read'):        # It's a file-type object.
#     175             markup = markup.read()
# --> 176         elif len(markup) <= 256:
#     177             # Print out warnings for a couple beginner problems
#     178             # involving passing non-markup to Beautiful Soup.
#
# TypeError: object of type 'float' has no len()

# %%
data
# Out:
#             DocId                                           Fulltext
# 1       309114555                               CHAUSSURES DE MARCHE
# 2       389148456                     Patent publication information
# 3       315295116           Médicament a base de dérivé de pyrazole.
# 4       380854758        Tracteur individuel a chenille pour skieur.
# 5       315289141       Médicament a base de dérivé de théophylline.
# 6       389353526                     Patent publication information
# 7       316646160           Perfectionnements aux plafonds suspendus
# 8       380845117                     Patent publication information
# 9       317083839                     Patent publication information
# 10      389397637                     Patent publication information
# 11      315289983               Correcteur de troubles métaboliques.
# 12      315290816       Nouveau correcteur de troubles métaboliques.
# 13      314991148     Zinc pyrolusite based batteries with polyamide
# ...

# %%
import fileinput

with fileinput.input(files=('name.a0', 'name.a1', 'name.a2')) as f:
    for line in f:  
        process(line)

# %%
data.to_csv('C:\Users\k_lemo\Documents\Stage\Data_EPO\KIME\iu.csv', sep=',', encoding='utf-8', index=False)
