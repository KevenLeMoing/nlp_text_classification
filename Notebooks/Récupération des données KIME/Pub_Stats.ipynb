# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('\Users\k_lemo\Documents\Stage\Data_EPO\Publi_PubStats.csv')
#data = data.drop([''], axis=1)

# %%
data
# Out:
#          familyId   pubDocId
# 0        51996375  449674300
# 1        19223782  309114555
# 2        52358906  450707848
# 3         8787999  315295116
# 4         8788000  315289141
# 5        27350796  316646160
# 6        52576733  449673807
# 7        53017157  450707761
# 8        21977358  316931723
# 9         8781697  315289983
# 10        8781698  315290816
# 11       24404622  316238773
# 12       36644165  389650594
# 13       36644165  291465497
# 14       54290442  450312610
# 15       54609131  449673726
# 16       54609132  449673728
# 17       54252587  450075772
# 18       54848032  450312608
# 19       39472505  450464291
# 20       39472505  277889895
# 21       51688316  449674207
# 22       52814748  451150244
# 23       51483228  450707639
# 24       52462090  450075656
# 25       52462090  450075658
# 26       53039119  451616322
# 27       53015451  452040101
# 28       52573561  450312465
# 29       51932150  450920801
# ...           ...        ...
# ...

# %%
data['pubDocId']
# Out:
# 0          449674300
# 1          309114555
# 2          450707848
# 3          315295116
# 4          315289141
# 5          316646160
# 6          449673807
# 7          450707761
# 8          316931723
# 9          315289983
# 10         315290816
# 11         316238773
# 12         389650594
# 13         291465497
# 14         450312610
# 15         449673726
# 16         449673728
# 17         450075772
# 18         450312608
# 19         450464291
# 20         277889895
# 21         449674207
# 22         451150244
# 23         450707639
# 24         450075656
# 25         450075658
# 26         451616322
# 27         452040101
# 28         450312465
# 29         450920801
#              ...
# 2770608    450460128
# 2770609    450707869
# 2770610    451381723
# 2770611    450312495
# 2770612    450920978
# 2770613    451384964
# 2770614    451150381
# 2770615    449483789
# 2770616    451381872
# 2770617    451381886
# 2770618    451381797
# 2770619    451381700
# ...

# %%
data['pubDocId'].to_csv('C:\Users\k_lemo\Documents\Stage\Data_EPO\ID_pub2.csv', sep=',', encoding='utf-8', index=False)
#np.asarray(famID).tofile("C:\Users\k_lemo\Documents\Stage\Data_EPO\ID_fam.csv",sep=',')

# %%
data.columns[5:]

# columns=df.columns[1:]
# Out:
# Index([], dtype='object')

# %%
# Mise en forme de listes de mots

famID = data.as_matrix(columns=data.columns[0:1])
pubID = data.as_matrix(columns=data.columns[1:2])

# %%
famID
# Out:
# array([[51996375],
#        [19223782],
#        [52358906],
#        ...,
#        [54784413],
#        [44353168],
#        [44353168]], dtype=int64)

# %%
pubID
# Out:
# array([[449674300],
#        [309114555],
#        [450707848],
#        ...,
#        [450312624],
#        [449674335],
#        [336547681]], dtype=int64)

# %%
# Enregistrement des listes

np.asarray(famID).tofile("C:\Users\k_lemo\Documents\Stage\Data_EPO\ID_fam.csv",sep=',')
np.asarray(pubID).tofile("C:\Users\k_lemo\Documents\Stage\Data_EPO\ID_pub.csv",sep=',')
